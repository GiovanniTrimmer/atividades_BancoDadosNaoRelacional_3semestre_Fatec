# %%
# !pip install "pymongo"
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.7.0)

# %%
import pymongo

# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 16.2 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 13.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
#Baixando o DataSet em csv
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_BDNAORELACIONAL_2SEM2024/refs/heads/main/Coordenadas%20csv.csv"

# %%
#Convertendo um arquivo csv em um DataFrame Pandas
estadios_df = pd.read_csv(dataset)

# %%
#Visualizando os 5 primeiros registros do Dataframe
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
#Visualizando os 5 primeiros registros do Dataframe
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
#Convertendo em um dicionário
dicionario = estadios_df.to_dict('records')

# %%
#Visualizando o dicionario
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
#Estabelecendo uma variavel que será o cliente do servidor Mongo
cliente = MongoClient("mongodb+srv://giovannitrimmer:12345@clusterestadios.a6qyx.mongodb.net/?retryWrites=true&w=majority&appName=ClusterEstadios")

# %%
#Selecionando a base de dados
db = cliente.get_database('futebol')

# %%
#Inserindo os documentos na nova base de dados
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('671950e9017b8cfc9bf667bc'), ObjectId('671950e9017b8cfc9bf667bd'), ObjectId('671950e9017b8cfc9bf667be'), ObjectId('671950e9017b8cfc9bf667bf'), ObjectId('671950e9017b8cfc9bf667c0'), ObjectId('671950e9017b8cfc9bf667c1'), ObjectId('671950e9017b8cfc9bf667c2'), ObjectId('671950e9017b8cfc9bf667c3'), ObjectId('671950e9017b8cfc9bf667c4'), ObjectId('671950e9017b8cfc9bf667c5'), ObjectId('671950e9017b8cfc9bf667c6'), ObjectId('671950e9017b8cfc9bf667c7'), ObjectId('671950e9017b8cfc9bf667c8'), ObjectId('671950e9017b8cfc9bf667c9'), ObjectId('671950e9017b8cfc9bf667ca'), ObjectId('671950e9017b8cfc9bf667cb'), ObjectId('671950e9017b8cfc9bf667cc'), ObjectId('671950e9017b8cfc9bf667cd'), ObjectId('671950e9017b8cfc9bf667ce'), ObjectId('671950e9017b8cfc9bf667cf')], acknowledged=True)

# %%
#recuperando uma collection em uma variavel
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['clusterestadios-shard-00-02.a6qyx.mongodb.net:27017', 'clusterestadios-shard-00-01.a6qyx.mongodb.net:27017', 'clusterestadios-shard-00-00.a6qyx.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='ClusterEstadios', authsource='admin', replicaset='atlas-taoyd6-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('67193f62e4f941be9ee6d64c'),
#   'nome': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.57243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('671950e9017b8cfc9bf667bc'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('671950e9017b8cfc9bf667bd'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('671950e9017b8cfc9bf667be'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('671950e9017b8cfc9bf667bf'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c0'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c1'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c2'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c3'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c4'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c5'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c6'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c7'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c8'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('671950e9017b8cfc9bf667c9'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('671950e9017b8cfc9bf667ca'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('671950e9017b8cfc9bf667cb'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('671950e9017b8cfc9bf667cc'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('671950e9017b8cfc9bf667cd'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('671950e9017b8cfc9bf667ce'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('671950e9017b8cfc9bf667cf'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
#Estabelecendo um ponto central do mapa (Centro do Brasil)
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
# Converter em um Data Frame
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           67193f62e4f941be9ee6d64c
# nome                      Vila Belmiro
# capacidade                       21732
# latitude                     -23.57243
# longitude                    -46.20123
# Name: 0, dtype: object

# %%
#Criando um mapa a partr do ponto central
locationmap = folium.Map(location=[center_lat, center_lon], zoom_start=5, width=800, height=600)

# %%
#Recuperando a quantidade de pontos
qtde = len(df_convertido)

# %%
for i in range(qtde):
   lng = float(df_convertido.iloc[i]['longitude'])
   lat = float(df_convertido.iloc[i]['latitude'])
   description = 'Estádio' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
   folium.Marker([lat, lng],
          popup=description,
          icon = folium.Icon(color = 'red')).add_to(locationmap)

# %%
#Exibindo o mapa com as marcações
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b173e688ee0689d50b364e7267548e7c {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b173e688ee0689d50b364e7267548e7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b173e688ee0689d50b364e7267548e7c = L.map(
#                 &quot;map_b173e688ee0689d50b364e7267548e7c&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1678a380e8beab7e0632500bdf029f1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1678a380e8beab7e0632500bdf029f1b.addTo(map_b173e688ee0689d50b364e7267548e7c);
#
#
#             var marker_b8d8cf1d98f1b24857be82aa4747efec = L.marker(
#                 [-23.57243, -46.20123],
#                 {}
#             ).addTo(map_b173e688ee0689d50b364e7267548e7c);
#
#
#             var icon_1b5f3c8be9913e8fcc7f80e47f8353ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b8d8cf1d98f1b24857be82aa4747efec.setIcon(icon_1b5f3c8be9913e8fcc7f80e47f8353ba);
#
#
#         var popup_eb75621ea64e8a540a6e928067f54cf3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_19f9b78941bca2dff6124239893cd51b = $(`&lt;div id=&quot;html_19f9b78941bca2dff6124239893cd51b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstádioVila Belmiro&lt;br&gt; Capacidade: 21732&lt;/div&gt;`)[0];
#                 popup_eb75621ea64e8a540a6e928067f54cf3.setContent(html_19f9b78941bca2dff6124239893cd51b);
#
#
#
#         marker_b8d8cf1d98f1b24857be82aa4747efec.bindPopup(popup_eb75621ea64e8a540a6e928067f54cf3)
#         ;
#
#
#
#
#             var marker_53fb47f138652eb56ba860924b2bd10c = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_b173e688ee0689d50b364e7267548e7c);
#
#
#             var icon_68089b85148c85f5da28344d16393a5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_53fb47f138652eb56ba860924b2bd10c.setIcon(icon_68089b85148c85f5da28344d16393a5b);
#
#
#         var popup_b8638f7757a76f2f8ba9318ad6957bda = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25cd0c09f0caa95decefc71c8c5ef50c = $(`&lt;div id=&quot;html_25cd0c09f0caa95decefc71c8c5ef50c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstádioMaracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_b8638f7757a76f2f8ba9318ad6957bda.setContent(html_25cd0c09f0caa95decefc71c8c5ef50c);
#
#
#
#         marker_53fb47f138652eb56ba860924b2bd10c.bindPopup(popup_b8638f7757a76f2f8ba9318ad6957bda)
#         ;
#
#
#
#
#             var marker_856e6f0a5e9c12009577624fb8e8e632 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_b173e688ee0689d50b364e7267548e7c);
#
#
#             var icon_85e4f079e0a5f6e23a9971e6b93d5efb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_856e6f0a5e9c12009577624fb8e8e632.setIcon(icon_85e4f079e0a5f6e23a9971e6b93d5efb);
#
#
#         var popup_348705f60d6b05ed4b51783e50ed0cc3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14a60c53aa5ddfe1c4318d736df63afb = $(`&lt;div id=&quot;html_14a60c53aa5ddfe1c4318d736df63afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;EstádioMané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_348705f60d6b05ed4b51783e50ed0cc3.setContent(html_14a60c53aa5ddfe1c4318d736df63afb);
#
#
#
#         marker_856e6f0a5e9c12009577624fb8e8e632.bindPopup(popup_348705f60d6b05ed4b51783e50ed0cc3)
#         ;
#
#
#
#
#             var marker_c07ad2d69457b93da0baa261324ac93a = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_b173e688ee0689d50b364e7267548e7c);
#
#
#             var icon_cf1fa319da4afb0b9dba0a24c350acea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate
